# %%
import pandas as pd
import pypyodbc as odbc

# %%
df = pd.read_csv("Updated 2020 unemployment.csv")
df.head()
# Out:
#   Location Indicator Subject Measure  Year  Month Frequency     Value
# 0      AUS       HUR     TOT   PC_LF  2020      1         M  5.269611
# 1      AUS       HUR     TOT   PC_LF  2020      2         M  5.081623
# 2      AUS       HUR     TOT   PC_LF  2020      3         M  5.220101
# 3      AUS       HUR     TOT   PC_LF  2020      4         M  6.358871
# 4      AUS       HUR     TOT   PC_LF  2020      5         M  7.068942

# %%
columns = df.columns

df_data = df[columns]
records = df_data.values.tolist()

records
# Out:
# PC_LF', 2020, 5, 'M', 4.309348],
#  ['MEX', 'HUR', 'TOT', 'PC_LF', 2020, 6, 'M', 5.5050550000000005],
#  ['MEX', 'HUR', 'TOT', 'PC_LF', 2020, 7, 'M', 5.156418],
#  ['MEX', 'HUR', 'TOT', 'PC_LF', 2020, 8, 'M', 4.960909],
#  ['MEX', 'HUR', 'TOT', 'PC_LF', 2020, 9, 'M', 4.693516000000002],
#  ['MEX', 'HUR', 'TOT', 'PC_LF', 2020, 10, 'M', 4.589718],
#  ['NLD', 'HUR', 'TOT', 'PC_LF', 2020, 1, 'M', 3.0],
#  ['NLD', 'HUR', 'TOT', 'PC_LF', 2020, 2, 'M', 2.9],
#  ['NLD', 'HUR', 'TOT', 'PC_LF', 2020, 3, 'M', 2.9],
#  ['NLD', 'HUR', 'TOT', 'PC_LF', 2020, 4, 'M', 3.4],
#  ['NLD', 'HUR', 'TOT', 'PC_LF', 2020, 5, 'M', 3.6],
#  ['NLD', 'HUR', 'TOT', 'PC_LF', 2020, 6, 'M', 4.3],
#  ['NLD', 'HUR', 'TOT', 'PC_LF', 2020, 7, 'M', 4.5],
#  ['NLD', 'HUR', 'TOT', 'PC_LF', 2020, 8, 'M', 4.6],
#  ['NLD', 'HUR', 'TOT', 'PC_LF', 2020, 9, 'M', 4.4],
#  ['NLD', 'HUR', 'TOT', 'PC_LF', 2020, 10, 'M', 4.3],
#  ['NOR', 'HUR', 'TOT', 'PC_LF', 2020, 1, 'M', 3.7],
#  ['NOR', 'HUR', 'TOT', 'PC_LF', 2020, 2, 'M', 3.5],
# ...
